# %% [markdown]
# # Key features of jupyter Notebooks
# - Documented Data Science
# - Reproducible Science
# - Presentation of Results
# - Support of Julia, Python, and R

# %% [markdown]
# Below is how we calculate the numbers of seconds in a year

# %%
365 * 24 *60 *60
# Out:
# 31536000

# %%
_ / 1e6
# undersocre refers to the output the last cell executed
# 1e6 == 10 to the power of 6 which is 1 million
# so the result is 31.536 million
# Out:
# 31.536

# %%
# second in a leap year(闰年)
366 * 24 *60 *60
# Out:
# 31622400

# %%
_ / 1e6
# Out:
# 31.6224

# %% [markdown]
# # This is a markdown cell use for code documentation
# ## This is heading 2
# ### This is heading 3
# #### This is heading 4
# Hi!
#
# - One fish
# - Two fish
# * Three fish
#
# **example text**
#
# *example text*
#
# http://google.com

# %% [markdown]
# we us double dollar sign for math equation, everything inside $$ will be transform into math equation

# %% [markdown]
# This is a **Latex ** equation example:
# $\int_0^\infty x^{-\alpha}$

# %%
# %matplotlib inline
from matplotlib.pyplot import plot
plot([0,1,0,1])

# %% [markdown]
# This is a plot using matplotlib of a vector.
